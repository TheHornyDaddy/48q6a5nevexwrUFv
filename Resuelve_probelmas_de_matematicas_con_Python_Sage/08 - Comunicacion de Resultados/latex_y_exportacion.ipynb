# %%
f(x) = x*exp(x)
g(x) = (x^2)*cos(2*x)
h(x) = (x^2 + x - 2) / (x - 4)

# %%
n(integral(g(x) , x , 0,1))
n(integral(h(x) , x , 0,1))
# Out:
# 0.321722695867944

# %%
integral(f(x) , x)
integral(g(x) , x)
integral(h(x) , x)
# Out:
# 1/2*x^2 + 5*x + 18*log(x - 4)

# %%
# Ver una función en formato latex
show(f(x))
# Out:
# x*e^x

# %%
# Ver código latex de un resultado
latex(f(x))
# Out:
# x e^{x}

# %%
# Su integral en formato latex con su respectivo código
show(integral(f(x) , x))
latex(integral(f(x) , x))
# Out:
# (x - 1)*e^x
# {\left(x - 1\right)} e^{x}

# %% [markdown]
# # Títuolo 1
# ### Título 3
# ###### Título 6
# ...
# *cursiva* **negrita**
# 1. lista numerada
# 2. lista numerada con fórmula en LaTex: $\alpha = \sum_{i}^{\infty}\frac{1}{2^i}$
#
# | Tables        | Are           | Cool  |
# | ------------- |:-------------:| -----:|
# | col 3 is      | right-aligned |\$1600 |
# | col 2 is      | centered      |  \$12 |
# | zebra stripes | are neat      |   \$1 |
#
# Esto es un ejemplo de LaTex en Python
#
# - Enumeración
#   $$\int_{0}^{\infty}e^{x^{2}}$$<img src="attachment:asintota_oblicua.svg" style="max-width:100%">

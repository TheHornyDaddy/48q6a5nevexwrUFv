# %%
import pandas as pd

# %%
data = pd.read_csv('DatosDemograficosT.csv')

# %%
# Notemos que sólo se aprecian las primeras y últimas cinco filas del
# DataFrame
print(data)
# Out:
#           Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 0                   Aruba            ABW             10.244
# 1             Afghanistan            AFG             35.253
# 2                  Angola            AGO             45.985
# 3                 Albania            ALB             12.877
# 4    United Arab Emirates            ARE             11.044
# ..                    ...            ...                ...
# 190           Yemen, Rep.            YEM             32.947
# 191          South Africa            ZAF             20.850
# 192      Congo, Dem. Rep.            COD             42.394
# 193                Zambia            ZMB             40.471
# 194              Zimbabwe            ZWE             35.715
#
#      Usuarios de Internet   Grupo de ingresos
# 0                    78.9        Ingreso alto
# 1                     5.9        Ingreso bajo
# 2                    19.1  Ingreso medio alto
# 3                    57.2  Ingreso medio alto
# ...

# %%
data
# Out:
#           Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 0                   Aruba            ABW             10.244
# 1             Afghanistan            AFG             35.253
# 2                  Angola            AGO             45.985
# 3                 Albania            ALB             12.877
# 4    United Arab Emirates            ARE             11.044
# ..                    ...            ...                ...
# 190           Yemen, Rep.            YEM             32.947
# 191          South Africa            ZAF             20.850
# 192      Congo, Dem. Rep.            COD             42.394
# 193                Zambia            ZMB             40.471
# 194              Zimbabwe            ZWE             35.715
#
#      Usuarios de Internet   Grupo de ingresos
# 0                    78.9        Ingreso alto
# 1                     5.9        Ingreso bajo
# 2                    19.1  Ingreso medio alto
# 3                    57.2  Ingreso medio alto
# ...

# %%
# Esto se debe a la configuración inicial de Python

# %%
# Para ca,biar esto, escribamos el siguiente comando:
pd.set_option('display.max_rows', None)

# %%
data
# Out:
#                     Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 0                             Aruba            ABW             10.244
# 1                       Afghanistan            AFG             35.253
# 2                            Angola            AGO             45.985
# 3                           Albania            ALB             12.877
# 4              United Arab Emirates            ARE             11.044
# 5                         Argentina            ARG             17.716
# 6                           Armenia            ARM             13.308
# 7               Antigua and Barbuda            ATG             16.447
# 8                         Australia            AUS             13.200
# 9                           Austria            AUT              9.400
# 10                       Azerbaijan            AZE             18.300
# 11                          Burundi            BDI             44.151
# ...
